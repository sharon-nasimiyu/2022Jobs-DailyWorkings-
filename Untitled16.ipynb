# %% [markdown]
# <a href="https://colab.research.google.com/github/sharon-nasimiyu/2022WebProject/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installation of beautiful soup which will be used in extraction of data
# !pip3 install beautifulsoup4

# %%
#importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
#scrapping the best selling books in amazon which are updated hourly and most of them are the lately reviewed and trending books
no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'a-section a-spacing-none aok-relative'}):
        #print(d)
        name = d.find('span', attrs={'class':'zg-text-center-align'})
        n = name.find_all('img', alt=True)
        #print(n[0]['alt'])
        author = d.find('a', attrs={'class':'a-size-small a-link-child'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('a', attrs={'class':'a-size-small a-link-normal'})
        price = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(n[0]['alt'])
        else:
            all1.append("unknown-product")

        if author is not None:
            #print(author.text)
            all1.append(author.text)
        elif author is None:
            author = d.find('span', attrs={'class':'a-size-small a-color-base'})
            if author is not None:
                all1.append(author.text)
            else:    
                all1.append('0')

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')

        if users_rated is not None:
            #print(price.text)
            all1.append(users_rated.text)
        else:
            all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

# %%
#saving the extracted data frame as csv file
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Book Name','Author','Rating','Customers_Rated', 'Price'])
df.to_csv('amazonlately_products.csv', index=False, encoding='utf-8')

# %%
#reading the savedv file
df = pd.read_csv("amazonlately_products.csv")
df.shape
(100, 5)
df.head(61)
# Out:
#                                             Book Name  ...    Price
# 0                             The Psychology of Money  ...  ₹240.00
# 1   Atomic Habits: The life-changing million copy ...  ...  ₹480.00
# 2                                        DO EPIC SHIT  ...  ₹298.00
# 3   Rich Dad Poor Dad: What the Rich Teach Their K...  ...  ₹243.00
# 4   My First Library: Boxset of 10 Board Books for...  ...  ₹349.00
# 5   Ikigai: The Japanese secret to a long and happ...  ...  ₹310.00
# 6                                Word Power Made Easy  ...   ₹92.00
# 7   Grandma's Bag of Stories: Collection of 20+ Il...  ...  ₹147.00
# 8   27 Years UPSC IAS/ IPS Prelims Topic-wise Solv...  ...  ₹351.00
# 9                                       The Alchemist  ...  ₹201.00
# 10  My First Book of Pencil Control : Practice Pat...  ...   ₹89.00
# 11                The Power of Your Subconscious Mind  ...  ₹125.00
# 12  The Almanack Of Naval Ravikant: A Guide to Wea...  ...  ₹232.00
# ...

# %%
#reprocessing the data and dropping some aspects such as we know that the rating is out of 5 so as we just remain with bare ratings
df['Rating'] = df['Rating'].apply(lambda x: x.split()[0])
df['Rating'] = pd.to_numeric(df['Rating'])
df["Price"] = df["Price"].str.replace('₹', '')
df["Price"] = df["Price"].str.replace(',', '')
df['Price'] = df['Price'].apply(lambda x: x.split('.')[0])
df['Price'] = df['Price'].astype(int)
df["Customers_Rated"] = df["Customers_Rated"].str.replace(',', '')
df['Customers_Rated'] = pd.to_numeric(df['Customers_Rated'], errors='ignore')
df.head()
# Out:
#                                            Book Name  ... Price
# 0                            The Psychology of Money  ...   240
# 1  Atomic Habits: The life-changing million copy ...  ...   480
# 2                                       DO EPIC SHIT  ...   298
# 3  Rich Dad Poor Dad: What the Rich Teach Their K...  ...   243
# 4  My First Library: Boxset of 10 Board Books for...  ...   349
#
# [5 rows x 5 columns]

# %%
#Sorting the books with the most rated books which most likely will be among the latelty reviewed books
data = df.sort_values(["Customers_Rated"], axis=0, ascending=False)[:21]
data
# Out:
#                                             Book Name  ... Price
# 9                                       The Alchemist  ...   201
# 20  The Subtle Art of Not Giving a F*ck: A Counter...  ...   303
# 3   Rich Dad Poor Dad: What the Rich Teach Their K...  ...   243
# 11                The Power of Your Subconscious Mind  ...   125
# 32                The Power of Your Subconscious Mind  ...    99
# 4   My First Library: Boxset of 10 Board Books for...  ...   349
# 33              Sapiens: A Brief History of Humankind  ...   345
# 6                                Word Power Made Easy  ...    92
# 1   Atomic Habits: The life-changing million copy ...  ...   480
# 40  The Intelligent Investor (English) Paperback –...  ...   449
# 5   Ikigai: The Japanese secret to a long and happ...  ...   310
# 18                           It Ends With Us: A Novel  ...   374
# 34                         The Richest Man in Babylon  ...    99
# ...

# %% [markdown]
# # New Section
